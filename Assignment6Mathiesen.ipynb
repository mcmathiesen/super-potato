# %% [markdown]
# <a href="https://colab.research.google.com/github/mcmathiesen/super-potato/blob/main/Assignment6Mathiesen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from pathlib import Path

# %%
from textblob import TextBlob

# %%
blob = TextBlob(Path('Hamlet.txt').read_text())

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
items = blob.word_counts.items()

# %%
items = [item for item in items if item[0] not in stop_words]

# %%
from operator import itemgetter

# %%
sorted_items = sorted(items, key=itemgetter(1), reverse=True)

# %%
sorted_items
# Out:
# [('’', 1067),
#  ('hamlet', 478),
#  ('lord', 222),
#  ('king', 205),
#  ('horatio', 156),
#  ('polonius', 125),
#  ('queen', 120),
#  ('shall', 116),
#  ('laertes', 108),
#  ('good', 107),
#  ('come', 106),
#  ('thou', 105),
#  ('let', 104),
#  ('project', 89),
#  ('ophelia', 87),
#  ('may', 86),
#  ('thy', 86),
#  ('would', 81),
#  ('like', 80),
#  ('know', 79),
#  ('rosencrantz', 78),
#  ('well', 76),
#  ('tis', 74),
#  ('sir', 73),
#  ('us', 72),
#  ('father', 70),
#  ('go', 70),
#  ('must', 69),
#  ('enter', 68),
#  ('guildenstern', 66),
#  ('love', 66),
#  ('hath', 64),
#  ('give', 63),
#  ('speak', 63),
#  ('first', 63),
#  ('upon', 59),
#  ('thee', 58),
#  ('make', 58),
#  ('man', 57),
#  ('say', 56),
#  ('th', 56),
#  ('gutenberg-tm', 56),
#  ('work', 55),
#  ('much', 50),
#  ('see', 50),
#  ('think', 48),
#  ('one', 48),
#  ('marcellus', 47),
#  ('clown', 47),
#  ('mother', 45),
#  ('scene', 44),
#  ('heaven', 44),
#  ('time', 44),
#  ('—', 43),
#  ('thus', 42),
# ...

# %%
top20 = sorted_items[1:21]

# %%
top20
# Out:
# [('hamlet', 478),
#  ('lord', 222),
#  ('king', 205),
#  ('horatio', 156),
#  ('polonius', 125),
#  ('queen', 120),
#  ('shall', 116),
#  ('laertes', 108),
#  ('good', 107),
#  ('come', 106),
#  ('thou', 105),
#  ('let', 104),
#  ('project', 89),
#  ('ophelia', 87),
#  ('may', 86),
#  ('thy', 86),
#  ('would', 81),
#  ('like', 80),
#  ('know', 79),
#  ('rosencrantz', 78)]

# %%
df = pd.DataFrame(top20, columns=['word', 'count'])

# %%
df
# Out:
#            word  count
# 0        hamlet    478
# 1          lord    222
# 2          king    205
# 3       horatio    156
# 4      polonius    125
# 5         queen    120
# 6         shall    116
# 7       laertes    108
# 8          good    107
# 9          come    106
# 10         thou    105
# 11          let    104
# 12      project     89
# 13      ophelia     87
# 14          may     86
# 15          thy     86
# 16        would     81
# 17         like     80
# 18         know     79
# 19  rosencrantz     78

# %%
axes = df.plot.bar(x='word', y='count', legend=False)

import matplotlib.pyplot as plt

plt.gcf().tight_layout()

# %%
text = Path('Hamlet.txt').read_text()

# %%
import imageio

# %%
mask_image = imageio.imread('mask_oval.png')

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(width=1000, height=1000, 
    colormap='prism', mask=mask_image, background_color='white')

# %%
wordcloud = wordcloud.generate(text)

# %%
plt.imshow(wordcloud)
